# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhigna-Nadupalli/ABInBev/blob/main/CaseStudy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.graph_objects as go
import plotly.offline as po
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import matplotlib.pyplot as plt
import plotly.express as px
import random
import plotly.figure_factory as ff
from plotly import tools
from plotly.subplots import make_subplots
from plotly.offline import iplot
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("/content/Germany_Jan19Feb19.xlsx")
df
# Out:
#                                         mkt_tag   prod_tag     per_tag  \
# 0      M000000000001000151400000000000010005732  P03221571  FEB19-1002
# 1      M000000000001000151400000000000010005732  P03216042  FEB19-1002
# 2      M000000000001000151400000000000010005732  P03169284  FEB19-1002
# 3      M000000000001000151400000000000010005732  P03198037  FEB19-1002
# 4      M000000000001000151400000000000010005732  P03172524  FEB19-1002
# ...                                         ...        ...         ...
# 44326  M000000000001000151400000000000010005732  P03172156  JAN19-1002
# 44327  M000000000001000151400000000000010005732  P03172449  JAN19-1002
# 44328  M000000000001000151400000000000010005732  P03215493  JAN19-1002
# 44329  M000000000001000151400000000000010005732  P03221446  JAN19-1002
# 44330  M000000000001000151400000000000010005732  P03178665  JAN19-1002
#
#        sales_units  units_any_promo  volume_hl  volume_any_promo_in_litres  \
# ...

# %%
df1 = pd.read_excel("/content/Germany_Jul19Aug19.xlsx")
df1
# Out:
#                                         mkt_tag   prod_tag     per_tag  \
# 0      M000000000001000151400000000000010005732  P03221571  AUG19-1002
# 1      M000000000001000151400000000000010005732  P03216042  AUG19-1002
# 2      M000000000001000151400000000000010005732  P03169284  AUG19-1002
# 3      M000000000001000151400000000000010005732  P03172524  AUG19-1002
# 4      M000000000001000151400000000000010005732  P03215791  AUG19-1002
# ...                                         ...        ...         ...
# 45084  M000000000001000151400000000000010005732  P03172163  JUL19-1002
# 45085  M000000000001000151400000000000010005732  P03197616  JUL19-1002
# 45086  M000000000001000151400000000000010005732  P03179319  JUL19-1002
# 45087  M000000000001000151400000000000010005732  P03215095  JUL19-1002
# 45088  M000000000001000151400000000000010005732  P03178868  JUL19-1002
#
#        sales_units  units_any_promo  volume_hl  volume_any_promo_in_litres  \
# ...

# %%
df2 = pd.read_excel("/content/Germany_Mar19Apr19.xlsx")
df2
# Out:
#                                         mkt_tag   prod_tag     per_tag  \
# 0      M000000000001000151400000000000010005732  P03222041  APR19-1002
# 1      M000000000001000151400000000000010005732  P03169180  APR19-1002
# 2      M000000000001000151400000000000010005732  P03186826  APR19-1002
# 3      M000000000001000151400000000000010005732  P03204935  APR19-1002
# 4      M000000000001000151400000000000010005732  P03191841  APR19-1002
# ...                                         ...        ...         ...
# 44745  M000000000001000151400000000000010005732  P03186134  MAR19-1002
# 44746  M000000000001000151400000000000010005732  P03348329  MAR19-1002
# 44747  M000000000001000151400000000000010005732  P03186135  MAR19-1002
# 44748  M000000000001000151400000000000010005732  P03198329  MAR19-1002
# 44749  M000000000001000151400000000000010005732  P03216041  MAR19-1002
#
#        sales_units  units_any_promo  volume_hl  volume_any_promo_in_litres  \
# ...

# %%
df3 = pd.read_excel("/content/Germany_May19Jun19.xlsx")
df3
# Out:
#                                         mkt_tag   prod_tag     per_tag  \
# 0      M000000000001000151400000000000010005732  P03222041  JUN19-1002
# 1      M000000000001000151400000000000010005732  P03169180  JUN19-1002
# 2      M000000000001000151400000000000010005732  P03179178  JUN19-1002
# 3      M000000000001000151400000000000010005732  P03186826  JUN19-1002
# 4      M000000000001000151400000000000010005732  P03204935  JUN19-1002
# ...                                         ...        ...         ...
# 45121  M000000000001000151400000000000010005732  P03221445  MAY19-1002
# 45122  M000000000001000151400000000000010005732  P03172156  MAY19-1002
# 45123  M000000000001000151400000000000010005732  P03172449  MAY19-1002
# 45124  M000000000001000151400000000000010005732  P03215493  MAY19-1002
# 45125  M000000000001000151400000000000010005732  P03178665  MAY19-1002
#
#        sales_units  units_any_promo  volume_hl  volume_any_promo_in_litres  \
# ...

# %%
df4 = pd.read_excel("/content/Germany_Nov18Dec18.xlsx")
df4
# Out:
#                                         mkt_tag   prod_tag     per_tag  \
# 0      M000000000001000151400000000000010005732  P03216042  DEC18-1002
# 1      M000000000001000151400000000000010005732  P03169284  DEC18-1002
# 2      M000000000001000151400000000000010005732  P03172524  DEC18-1002
# 3      M000000000001000151400000000000010005732  P03215791  DEC18-1002
# 4      M000000000001000151400000000000010005732  P03224228  DEC18-1002
# ...                                         ...        ...         ...
# 44042  M000000000001000151400000000000010005732  P03205199  NOV18-1002
# 44043  M000000000001000151400000000000010005732  P03197616  NOV18-1002
# 44044  M000000000001000151400000000000010005732  P03179319  NOV18-1002
# 44045  M000000000001000151400000000000010005732  P03215095  NOV18-1002
# 44046  M000000000001000151400000000000010005732  P03178868  NOV18-1002
#
#        sales_units  units_any_promo  volume_hl  volume_any_promo_in_litres  \
# ...

# %%
df5 = pd.read_excel("/content/Germany_Sep19Oct19.xlsx")
df5
# Out:
#                                         mkt_tag   prod_tag     per_tag  \
# 0      M000000000001000151400000000000010005732  P03178869  OCT19-1002
# 1      M000000000001000151400000000000010005732  P03205109  OCT19-1002
# 2      M000000000001000151400000000000010005732  P03205110  OCT19-1002
# 3      M000000000001000151400000000000010005732  P03171768  OCT19-1002
# 4      M000000000001000151400000000000010005732  P03171769  OCT19-1002
# ...                                         ...        ...         ...
# 44979  M000000000001000151400000000000010005732  P03172156  SEP19-1002
# 44980  M000000000001000151400000000000010005732  P03172449  SEP19-1002
# 44981  M000000000001000151400000000000010005732  P03215493  SEP19-1002
# 44982  M000000000001000151400000000000010005732  P03213799  SEP19-1002
# 44983  M000000000001000151400000000000010005732  P03178665  SEP19-1002
#
#        sales_units  units_any_promo  volume_hl  volume_any_promo_in_litres  \
# ...

# %%
df6 = df.append(df1)

# %%
df7 = df6.append(df2)

# %%
df8 = df7.append(df3)

# %%
df9 = df8.append(df4)

# %%
df10 = df9.append(df5)

# %%
pd.set_option("display.max_columns", None)
df10.reset_index()
df10
# Out:
#                                         mkt_tag   prod_tag     per_tag  \
# 0      M000000000001000151400000000000010005732  P03221571  FEB19-1002
# 1      M000000000001000151400000000000010005732  P03216042  FEB19-1002
# 2      M000000000001000151400000000000010005732  P03169284  FEB19-1002
# 3      M000000000001000151400000000000010005732  P03198037  FEB19-1002
# 4      M000000000001000151400000000000010005732  P03172524  FEB19-1002
# ...                                         ...        ...         ...
# 44979  M000000000001000151400000000000010005732  P03172156  SEP19-1002
# 44980  M000000000001000151400000000000010005732  P03172449  SEP19-1002
# 44981  M000000000001000151400000000000010005732  P03215493  SEP19-1002
# 44982  M000000000001000151400000000000010005732  P03213799  SEP19-1002
# 44983  M000000000001000151400000000000010005732  P03178665  SEP19-1002
#
#        sales_units  units_any_promo  volume_hl  volume_any_promo_in_litres  \
# ...

# %%
a = df10.columns.tolist()
a
# Out:
# ['mkt_tag',
#  'prod_tag',
#  'per_tag',
#  'sales_units',
#  'units_any_promo',
#  'volume_hl',
#  'volume_any_promo_in_litres',
#  'sales_value_in_local_currency',
#  'value_sales_eur',
#  'value_sales_usd',
#  'value_any_promo_in_local_currency',
#  'value_any_promo_eur',
#  'value_any_promo_usd',
#  'distribution_numeric',
#  'distribution_weighted',
#  'distribution_wtd_any_promo',
#  'distribution_wtd_feature_and_display',
#  'distribution_wtd_display',
#  'distribution_wtd_feature',
#  'total_distribution_points',
#  'volume_feature_and_display_in_litres',
#  'volume_display_in_litres',
#  'volume_feature_in_litres',
#  'store_count',
#  'units_feature_and_display',
#  'units_display',
#  'units_feature',
#  'value_feature_and_display_in_local_currency',
#  'value_feature_and_display_eur',
#  'value_feature_and_display_usd',
#  'value_display_in_local_currency',
#  'value_display_eur',
#  'value_display_usd',
#  'value_feature_in_local_currency',
#  'value_feature_eur',
# ...

# %%
for i in a:
    print(i)
    print(df10[i].isnull().sum())
# Out:
# mkt_tag
# 0
# prod_tag
# 0
# per_tag
# 0
# sales_units
# 0
# units_any_promo
# 268327
# volume_hl
# 0
# volume_any_promo_in_litres
# 0
# sales_value_in_local_currency
# 0
# value_sales_eur
# 0
# value_sales_usd
# 0
# value_any_promo_in_local_currency
# 0
# value_any_promo_eur
# 0
# value_any_promo_usd
# 0
# distribution_numeric
# 0
# distribution_weighted
# 0
# distribution_wtd_any_promo
# 0
# distribution_wtd_feature_and_display
# 0
# distribution_wtd_display
# 0
# distribution_wtd_feature
# 0
# total_distribution_points
# 0
# volume_feature_and_display_in_litres
# 268327
# volume_display_in_litres
# 268327
# volume_feature_in_litres
# 268327
# store_count
# 0
# units_feature_and_display
# 268327
# units_display
# 268327
# units_feature
# 268327
# value_feature_and_display_in_local_currency
# 268327
# value_feature_and_display_eur
# 268327
# value_feature_and_display_usd
# 268327
# value_display_in_local_currency
# 268327
# value_display_eur
# 268327
# value_display_usd
# 268327
# ...

# %%
df10.dtypes
# Out:
# mkt_tag             object
# prod_tag            object
# per_tag             object
# sales_units          int64
# units_any_promo    float64
#                     ...
# ins_usr_id19        object
# ins_gmt_ts20         int64
# upd_usr_id21        object
# upd_gmt_ts22         int64
# load_job_nr23        int64
# Length: 119, dtype: object

# %%
for i in a:
    if (len(df10[i].value_counts().values.tolist()) < 15) & (len(df10[i].value_counts().values.tolist()) > 1 ):
        print(i)
        print(df10[i].value_counts())
        print("--------------------------------------------------------------------------")
# Out:
# per_tag
# JUL19-1002    22738
# OCT19-1002    22712
# JUN19-1002    22576
# MAY19-1002    22550
# APR19-1002    22512
# AUG19-1002    22351
# SEP19-1002    22272
# JAN19-1002    22251
# MAR19-1002    22238
# DEC18-1002    22081
# FEB19-1002    22080
# NOV18-1002    21966
# Name: per_tag, dtype: int64
# --------------------------------------------------------------------------
# distribution_wtd_feature_and_display
# 0    266718
# 1      1155
# 2       293
# 3       102
# 4        40
# 5        17
# 6         1
# 9         1
# Name: distribution_wtd_feature_and_display, dtype: int64
# --------------------------------------------------------------------------
# distribution_wtd_display
# 0     265807
# 1       1821
# 2        441
# 3        155
# 4         70
# 5         21
# 6          8
# 7          2
# 10         1
# 8          1
# Name: distribution_wtd_display, dtype: int64
# --------------------------------------------------------------------------
# store_count
# 52606    44377
# ...

# %%
c = ['volume_hl','volume_any_promo_in_litresm','sales_value_in_local_currency','value_sales_eur','value_sales_usd','sales_units','units_any_prom','value_any_promo_in_local_currency','value_any_promo_eur','value_any_promo_usd','distribution_numeric','distribution_weighted']

# %%
df11 = df10.groupby('beer_category').agg({'volume_hl' : 'mean','volume_any_promo_in_litres' : 'mean',
                                        'sales_value_in_local_currency' : 'mean',
                                        'value_sales_eur' : 'mean','value_sales_usd' : 'mean','sales_units' : 'mean',
                                        'value_any_promo_in_local_currency' : 'mean',
                                        'value_any_promo_eur' : 'mean','value_any_promo_usd' : 'mean',
                                        'distribution_numeric' : 'mean','distribution_weighted' : 'mean'})
df11
# Out:
#                     volume_hl  volume_any_promo_in_litres  \
# beer_category
# FLAVOURED & WHEAT  130.903389                   29.456727
# LAGER              289.667093                   90.979544
# STYLES              69.083437                   11.738991
#
#                    sales_value_in_local_currency  value_sales_eur  \
# beer_category
# FLAVOURED & WHEAT                   20486.856979     20486.856979
# LAGER                               37811.381356     37811.381356
# STYLES                              10541.303210     10541.303210
#
#                    value_sales_usd   sales_units  \
# beer_category
# FLAVOURED & WHEAT     24944.764375   9081.602394
# LAGER                 46039.111674  15856.488678
# STYLES                12835.056252   7103.753042
#
#                    value_any_promo_in_local_currency  value_any_promo_eur  \
# beer_category
# FLAVOURED & WHEAT                        3907.897379          3907.897379
# ...

# %%
px.bar(data_frame=df11, barmode='group',
       title = "<b>beer category wise Analyzing</b>",template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df12 = df10.groupby('per_tag').agg({'volume_hl' : 'mean','volume_any_promo_in_litres' : 'mean',
                                        'sales_value_in_local_currency' : 'mean',
                                        'value_sales_eur' : 'mean','value_sales_usd' : 'mean','sales_units' : 'mean',
                                        'value_any_promo_in_local_currency' : 'mean',
                                        'value_any_promo_eur' : 'mean','value_any_promo_usd' : 'mean',
                                        'distribution_numeric' : 'mean','distribution_weighted' : 'mean'})
df12
# Out:
#              volume_hl  volume_any_promo_in_litres  \
# per_tag
# APR19-1002  262.694563                   81.821251
# AUG19-1002  224.631113                   65.453447
# DEC18-1002  201.510801                   59.495947
# FEB19-1002  188.457880                   54.419384
# JAN19-1002  213.982742                   58.831064
# JUL19-1002  286.662855                   85.586243
# JUN19-1002  238.127215                   69.826807
# MAR19-1002  191.965554                   53.908625
# MAY19-1002  232.221286                   71.293570
# NOV18-1002  191.534644                   53.532277
# OCT19-1002  231.745333                   69.573353
# SEP19-1002  198.939925                   58.950700
#
#             sales_value_in_local_currency  value_sales_eur  value_sales_usd  \
# per_tag
# APR19-1002                   35587.428038     35587.428038     43331.212687
# AUG19-1002                   31092.930518     31092.930518     37858.711467
# ...

# %%
px.bar(data_frame=df12, barmode='group',
       title = "<b>per tag wise Analyzing</b>",template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df13 = df10.groupby('global_segment').agg({'volume_hl' : 'mean','volume_any_promo_in_litres' : 'mean',
                                        'sales_value_in_local_currency' : 'mean',
                                        'value_sales_eur' : 'mean','value_sales_usd' : 'mean','sales_units' : 'mean',
                                        'value_any_promo_in_local_currency' : 'mean',
                                        'value_any_promo_eur' : 'mean','value_any_promo_usd' : 'mean',
                                        'distribution_numeric' : 'mean','distribution_weighted' : 'mean'})
df13
# Out:
#                    volume_hl  volume_any_promo_in_litres  \
# global_segment
# BLOND/ ALES        28.990487                    5.584353
# CLASSIC           288.808195                   90.336304
# EASY DRINKING     402.689487                  175.623472
# FRUIT/ FLAVOURED  137.164755                   30.902865
# SPIRITS           278.448016                   47.860372
# STOUT/ DARK       105.077996                   17.264488
# WHEAT BEER        119.275684                   27.463451
#
#                   sales_value_in_local_currency  value_sales_eur  \
# global_segment
# BLOND/ ALES                         6582.424772      6582.424772
# CLASSIC                            37473.049405     37473.049405
# EASY DRINKING                      82332.502037     82332.502037
# FRUIT/ FLAVOURED                   20553.846008     20553.846008
# SPIRITS                            77329.000502     77329.000502
# STOUT/ DARK                        14095.496296     14095.496296
# ...

# %%
px.bar(data_frame=df13, barmode='group',
       title = "<b>global segment wise Analyzing</b>",template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df14 = df10.groupby('abv_above_or_below_3_5').agg({'volume_hl' : 'mean','volume_any_promo_in_litres' : 'mean',
                                        'sales_value_in_local_currency' : 'mean',
                                        'value_sales_eur' : 'mean','value_sales_usd' : 'mean','sales_units' : 'mean',
                                        'value_any_promo_in_local_currency' : 'mean',
                                        'value_any_promo_eur' : 'mean','value_any_promo_usd' : 'mean',
                                        'distribution_numeric' : 'mean','distribution_weighted' : 'mean'})
df14
# Out:
#                          volume_hl  volume_any_promo_in_litres  \
# abv_above_or_below_3_5
# ALCOHOLIC               240.462030                   73.730574
# LOW ALCOHOLIC           126.541338                   27.309194
# NON ALCOHOLIC           197.359194                   44.726104
# NOT AVAILABLE            85.843812                   15.016545
#
#                         sales_value_in_local_currency  value_sales_eur  \
# abv_above_or_below_3_5
# ALCOHOLIC                                32194.669651     32194.669651
# LOW ALCOHOLIC                            18810.284636     18810.284636
# NON ALCOHOLIC                            28831.698671     28831.698671
# NOT AVAILABLE                            13412.263402     13412.263402
#
#                         value_sales_usd   sales_units  \
# abv_above_or_below_3_5
# ALCOHOLIC                  39200.198903  13560.007272
# LOW ALCOHOLIC              22903.413649  10960.602370
# ...

# %%
px.bar(data_frame=df14, barmode='group',
       title = "<b>abv_above_or_below_3_5 wise Analyzing</b>",template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df15 = df10.groupby('abv_grouping').agg({'volume_hl' : 'mean','volume_any_promo_in_litres' : 'mean',
                                        'sales_value_in_local_currency' : 'mean',
                                        'value_sales_eur' : 'mean','value_sales_usd' : 'mean','sales_units' : 'mean',
                                        'value_any_promo_in_local_currency' : 'mean',
                                        'value_any_promo_eur' : 'mean','value_any_promo_usd' : 'mean',
                                        'distribution_numeric' : 'mean','distribution_weighted' : 'mean'})
df15
# Out:
#                         volume_hl  volume_any_promo_in_litres  \
# abv_grouping
# 0.5%>ABV<3.5%          126.541338                   27.309194
# 3.5%>ABV<4.5%          188.025601                   31.351823
# 4.5%>ABV<5.5%          275.631318                   86.856847
# 5.5%>ABV<7.0%           59.831700                    8.818273
# 7.0%>ABV<7.5%           44.523085                    5.910705
# 7.5%>ABV<8.0%           76.048043                   15.137544
# >8.0%                   16.362476                    1.033823
# NON ALCOHOLIC          197.359194                   44.726104
# NOT STATED / ASSORTED   85.843812                   15.016545
#
#                        sales_value_in_local_currency  value_sales_eur  \
# abv_grouping
# 0.5%>ABV<3.5%                           18810.284636     18810.284636
# 3.5%>ABV<4.5%                           25226.020171     25226.020171
# 4.5%>ABV<5.5%                           36084.118545     36084.118545
# ...

# %%
px.bar(data_frame=df15, barmode='group',
       title = "<b>abv_grouping</b>",template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df16 = df10.groupby('colour_arc').agg({'volume_hl' : 'mean','volume_any_promo_in_litres' : 'mean',
                                        'sales_value_in_local_currency' : 'mean',
                                        'value_sales_eur' : 'mean','value_sales_usd' : 'mean','sales_units' : 'mean',
                                        'value_any_promo_in_local_currency' : 'mean',
                                        'value_any_promo_eur' : 'mean','value_any_promo_usd' : 'mean',
                                        'distribution_numeric' : 'mean','distribution_weighted' : 'mean'})
df16
# Out:
#                volume_hl  volume_any_promo_in_litres  \
# colour_arc
# AMBER/COPPER   73.481582                   16.973408
# ASSORTED       32.961595                   11.093058
# BLACK/DARK     63.788511                   10.810344
# BLONDE/GOLD   314.238446                   98.629513
# NOT STATED     78.663095                    8.583044
# RED/RUBY       60.396040                   12.776778
#
#               sales_value_in_local_currency  value_sales_eur  value_sales_usd  \
# colour_arc
# AMBER/COPPER                   12069.844456     12069.844456     14696.197550
# ASSORTED                       10675.974889     10675.974889     12999.002954
# BLACK/DARK                      9355.123263      9355.123263     11390.804591
# BLONDE/GOLD                    41667.377337     41667.377337     50734.154697
# NOT STATED                      9848.862906      9848.862906     11991.969745
# RED/RUBY                       11145.481548     11145.481548     13570.738074
#
# ...

# %%
px.bar(data_frame=df16, barmode='group',
       title = "<b>colour_arc</b>",template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df17 = df10.groupby('packaging_type').agg({'volume_hl' : 'mean','volume_any_promo_in_litres' : 'mean',
                                        'sales_value_in_local_currency' : 'mean',
                                        'value_sales_eur' : 'mean','value_sales_usd' : 'mean','sales_units' : 'mean',
                                        'value_any_promo_in_local_currency' : 'mean',
                                        'value_any_promo_eur' : 'mean','value_any_promo_usd' : 'mean',
                                        'distribution_numeric' : 'mean','distribution_weighted' : 'mean'})
df17
# Out:
#                                volume_hl  volume_any_promo_in_litres  \
# packaging_type
# CAN                           562.805604                   86.970831
# HOME DRAUGHT                   49.701362                    8.178484
# METAL BOTTLE                    0.000000                    0.000000
# NOT RETURNABLE GLASS BOTTLE    40.562240                    8.058769
# OTHER                           0.000000                    0.000000
# PET BOTTLE                   2545.730274                  242.512591
# RETURNABLE GLASS BOTTLE       198.108589                   65.473046
#
#                              sales_value_in_local_currency  value_sales_eur  \
# packaging_type
# CAN                                           74273.745922     74273.745922
# HOME DRAUGHT                                  10824.572127     10824.572127
# METAL BOTTLE                                    103.809524       103.809524
# NOT RETURNABLE GLASS BOTTLE                    8454.484035      8454.484035
# ...

# %%
px.bar(data_frame=df17, barmode='group',
       title = "<b>packaging_type</b>",template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cat = [
 'beer_category',
 'global_segment',
 'abv_above_or_below_3_5',
 'price_segmentation',
 'abv_grouping',
 'colour_arc',
 'packaging_type']

# %%
colors = px.colors.cyclical.Twilight
sns.set_theme(rc = {'figure.dpi': 250, 'axes.labelsize': 7, 
                    'axes.facecolor': '#FFFDE7', 'grid.color': '#fffdfa', 
                    'figure.facecolor': '#FFFDE7'}, font_scale = 0.55)
sns.countplot(x = df10['beer_category'], hue = df10['per_tag'], palette = colors, alpha = 1)
plt.show()

# %%
sns.set_theme(rc = {'figure.dpi': 250, 'axes.labelsize': 7, 
                    'axes.facecolor': '#FFFDE7', 'grid.color': '#fffdfa', 
                    'figure.facecolor': '#FFFDE7'}, font_scale = 0.55)
sns.countplot(x = df10['global_segment'], hue = df10['per_tag'], palette = colors, alpha = 1)
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_theme(rc = {'figure.dpi': 250, 'axes.labelsize': 7, 
                    'axes.facecolor': '#FFFDE7', 'grid.color': '#fffdfa', 
                    'figure.facecolor': '#FFFDE7'}, font_scale = 0.55)
sns.countplot(x = df10['abv_above_or_below_3_5'], hue = df10['per_tag'], palette = colors, alpha = 1)
plt.show()

# %%
sns.set_theme(rc = {'figure.dpi': 250, 'axes.labelsize': 7, 
                    'axes.facecolor': '#FFFDE7', 'grid.color': '#fffdfa', 
                    'figure.facecolor': '#FFFDE7'}, font_scale = 0.55)
sns.countplot(x = df10['price_segmentation'], hue = df10['per_tag'], palette = colors, alpha = 1)
plt.show()

# %%
sns.set_theme(rc = {'figure.dpi': 250, 'axes.labelsize': 7, 
                    'axes.facecolor': '#FFFDE7', 'grid.color': '#fffdfa', 
                    'figure.facecolor': '#FFFDE7'}, font_scale = 0.55)
sns.countplot(x = df10['abv_grouping'], hue = df10['per_tag'], palette = colors, alpha = 1)
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_theme(rc = {'figure.dpi': 250, 'axes.labelsize': 7, 
                    'axes.facecolor': '#FFFDE7', 'grid.color': '#fffdfa', 
                    'figure.facecolor': '#FFFDE7'}, font_scale = 0.55)
sns.countplot(x = df10['colour_arc'], hue = df10['per_tag'], palette = colors, alpha = 1)
plt.show()

# %%
sns.set_theme(rc = {'figure.dpi': 250, 'axes.labelsize': 7, 
                    'axes.facecolor': '#FFFDE7', 'grid.color': '#fffdfa', 
                    'figure.facecolor': '#FFFDE7'}, font_scale = 0.55)
sns.countplot(x = df10['packaging_type'], hue = df10['per_tag'], palette = colors, alpha = 1)
plt.xticks(rotation=45)
plt.show()
